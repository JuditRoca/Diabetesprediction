# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Carga fichero

# %%
df_original = pd.read_csv("../Data\Raw\ds_salaries.csv")

# %%
df_original.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
tasa_cambio = 0.92

df_original["salario_eur"] = df_original["salary_in_usd"] * tasa_cambio
df_original.drop(columns=["salary", 'salary_currency', 'salary_in_usd'], inplace=True)

# %%
variables = df_original.select_dtypes(include=['object']).columns

# %%
df = pd.get_dummies(df_original, columns=variables)

# %%
#Eliminar variables redundantes.
df_processed = df_original[['work_year','salario_eur', 'experience_level_mean', 'employment_type_encoded',
       'job_title_mean', 'company_location_mean', 'employee_location_mean',
       'company_size', 'remote_ratio']]

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
df.describe()
# Out:
#          work_year  remote_ratio    salario_eur  experience_level_EN  \
# count  3755.000000   3755.000000    3755.000000          3755.000000
# mean   2022.373635     46.271638  126564.758690             0.085220
# std       0.691448     48.589050   58011.175256             0.279246
# min    2020.000000      0.000000    4721.440000             0.000000
# 25%    2022.000000      0.000000   87400.000000             0.000000
# 50%    2022.000000      0.000000  124200.000000             0.000000
# 75%    2023.000000    100.000000  161000.000000             0.000000
# max    2023.000000    100.000000  414000.000000             1.000000
#
#        experience_level_EX  experience_level_MI  experience_level_SE  \
# count          3755.000000          3755.000000          3755.000000
# mean              0.030360             0.214381             0.670040
# std               0.171597             0.410447             0.470261
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             1.000000
# 75%               0.000000             0.000000             1.000000
# max               1.000000             1.000000             1.000000
#
#        employment_type_CT  employment_type_FL  employment_type_FT  ...  \
# count         3755.000000         3755.000000         3755.000000  ...
# mean             0.002663            0.002663            0.990146  ...
# std              0.051543            0.051543            0.098788  ...
# min              0.000000            0.000000            0.000000  ...
# 25%              0.000000            0.000000            1.000000  ...
# 50%              0.000000            0.000000            1.000000  ...
# 75%              0.000000            0.000000            1.000000  ...
# max              1.000000            1.000000            1.000000  ...
#
#        company_location_SI  company_location_SK  company_location_TH  \
# count          3755.000000          3755.000000          3755.000000
# mean              0.001065             0.000266             0.000799
# std               0.032625             0.016319             0.028258
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
#        company_location_TR  company_location_UA  company_location_US  \
# count          3755.000000          3755.000000          3755.000000
# mean              0.001332             0.001065             0.809587
# std               0.036471             0.032625             0.392679
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             1.000000
# 50%               0.000000             0.000000             1.000000
# 75%               0.000000             0.000000             1.000000
# max               1.000000             1.000000             1.000000
#
#        company_location_VN  company_size_L  company_size_M  company_size_S
# count          3755.000000     3755.000000     3755.000000     3755.000000
# mean              0.000266        0.120905        0.839680        0.039414
# std               0.016319        0.326061        0.366951        0.194604
# min               0.000000        0.000000        0.000000        0.000000
# 25%               0.000000        0.000000        1.000000        0.000000
# 50%               0.000000        0.000000        1.000000        0.000000
# 75%               0.000000        0.000000        1.000000        0.000000
# max               1.000000        1.000000        1.000000        1.000000
#
# [8 rows x 257 columns]

# %% [markdown]
# ## 2. Creación csv train y test

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df_original, test_size=0.2, random_state=42)

# %%
print(test_df.shape)
print(train_df.shape)
# Out:
# (751, 9)
# (3004, 9)

# %% [markdown]
# ## 3.Creación csv

# %%
def csv(nombre_archivo, archivo_guardar):

    ruta_archivo = '../Data/' + nombre_archivo + '.csv'
    archivo_guardar.to_csv(ruta_archivo, index=False)

# %%
csv("processed", df_original)

# %%
csv("test", test_df)

# %%
csv("train", train_df)
